# %%
import pandas as pd
from datetime import datetime

# %%
old_data = pd.read_csv('../Data/Production/matches.csv')
new_data = pd.read_csv('../Data/Staging/feature_table.csv')

# %%
old_data.head()
# Out:
#    Unnamed: 0         Player 1         Player 2           Winner     Score  \
# 0           0   Lleyton Hewitt  Guillermo Canas   Lleyton Hewitt    6364.0
# 1           1   Lleyton Hewitt    Roger Federer   Lleyton Hewitt    6462.0
# 2           2  Guillermo Canas    Tommy Robredo  Guillermo Canas    7564.0
# 3           3   Lleyton Hewitt  Gilles Elseneer   Lleyton Hewitt    6264.0
# 4           4    Roger Federer   Raemon Sluiter    Roger Federer  676464.0
#
#     Tournament Name  Year  Player 1 Ranking  Player 2 Ranking        Date  \
# 0  'S-Hertogenbosch  2001              -1.0              -1.0  2001-06-18
# 1  'S-Hertogenbosch  2001               6.0              15.0  2001-06-18
# 2  'S-Hertogenbosch  2001              61.0              69.0  2001-06-18
# 3  'S-Hertogenbosch  2001               6.0             323.0  2001-06-18
# 4  'S-Hertogenbosch  2001              15.0             107.0  2001-06-18
#
# ...

# %%
player_1 = 'Lleyton Hewitt'
player_2 = 'Roger Federer'
date = datetime(2011, 6, 18)
new_data[((new_data['Player 1'] == player_1) & (new_data['Player 2'] == player_2)) | ((new_data['Player 2'] == player_1) & (new_data['Player 1'] == player_2))]
# Out:
#        Unnamed: 0        Player 1        Player 2     Tournament Name  \
# 1618         1618  Lleyton Hewitt   Roger Federer    'S-Hertogenbosch
# 3634         3634   Roger Federer  Lleyton Hewitt               Miami
# 5703         5703  Lleyton Hewitt   Roger Federer               Paris
# 5715         5715   Roger Federer  Lleyton Hewitt  Tennis Masters Cup
# 8916         8916   Roger Federer  Lleyton Hewitt     Australian Open
# 9885         9885   Roger Federer  Lleyton Hewitt             Hamburg
# 10278       10278  Lleyton Hewitt   Roger Federer           Wimbledon
# 11065       11065  Lleyton Hewitt   Roger Federer             Us Open
# 11661       11661  Lleyton Hewitt   Roger Federer  Tennis Masters Cup
# 11662       11662  Lleyton Hewitt   Roger Federer  Tennis Masters Cup
# 12341       12341   Roger Federer  Lleyton Hewitt        Indian Wells
# 13277       13277   Roger Federer  Lleyton Hewitt           Wimbledon
# ...
